# %%
from portrait import Portrait, categories

# %%
categories['areas']
# Out:
# ['Data',
#  'Software Development',
#  'DevOps',
#  'Web Development',
#  'Community',
#  'Security']

# %%
p = Portrait()
fig, ax = p.fig, p.ax
p.add_python_area(categories['areas'][1])
p.add_favourite_object(categories['objects'][1])
p.add_water_preference(categories['waters'][1])
p.add_working_preference(categories['workings'][1])
p.add_travel_distance(categories['distances'][0])
p.add_games(categories['games'][0])
p.add_superpower(categories['powers'][1])
p.add_pyladies(categories['pyladies'][0])
p.save_portrait('../../portrait.pdf')

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.2.2'
