# %%
from pathlib import Path
from portrait import Portrait, categories

# %%
p = Portrait(image_path = Path.cwd().parents[0]/'images')
fig, ax = p.fig, p.ax
p.add_python_area(categories['areas'][4])
p.add_favourite_object(categories['objects'][1])
p.add_water_preference(categories['waters'][3])
p.add_working_preference(categories['workings'][1])
p.add_travel_distance(categories['distances'][2])
p.add_games(categories['games'][4])
p.add_superpower(categories['powers'][1])
p.add_pyladies(categories['pyladies'][1])
p.save_portrait('../../portrait.pdf')
